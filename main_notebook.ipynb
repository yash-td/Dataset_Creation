# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials 
import requests
import os
import time
import numpy as np
import re
from tqdm import tqdm
from configparser import ConfigParser

# %%
sleep_min = 1
sleep_max = 3
configur = ConfigParser()
configur.read('config.ini')
client_id = configur['main']['client_id']
client_secret = configur['main']['client_secret']
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) # sp is the instance of the spotipy api

# %%
data = pd.read_csv('/Users/ytkd/Desktop/LY_Artist_lyrics_genre_data_from_big5_mft_users_likes_final.csv')
data = data[data['lang_detect_spacy']=='en']
sample_dataset = data[:200]

# %%
artists = list(sample_dataset['Artist'])
titles = list(sample_dataset['title'])

# %% [markdown]
# </h2> Data Cleaning

# %%
def pre_process_text(text):
    text = text.lower()
    text = re.sub(r"[^\x00-\x7F]+'",' ', text)
    return text

# %%
'''
check how many artists and titles have special characters
'''
c = 0
for title in titles:
    if str(title).isascii():
        c+=1
print('The number of non ascii characters in our sample dataset titles are:- ', 200-c)
# Out:
# The number of non ascii characters in our sample dataset titles are:-  28

# %%
artists_clean = []
titles_clean = []

for i in tqdm(range(len(artists))):
    artists_clean.append(pre_process_text(artists[i]))
    titles_clean.append(pre_process_text(titles[i]))
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 143665.15it/s]

# %%
request_count = 0
start_time = time.time()
spotify_artists = []
check_dat = []
for i in tqdm(range(len(artists))):
    query = sp.search(f'artist:{artists_clean[i]} track:{titles_clean[i]}')
    if query['tracks']['items']:
        spotify_artists.append(query['tracks']['items'][0]['artists'][0]['name'])
        check_dat.append(query['tracks']['items'][0]['artists'][0]['name'])
    else:
        spotify_artists.append(artists[i])
        
    request_count+=1
    if request_count % 5 == 0:
        # print(str(request_count) + " requests sent")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        # print('Elapsed Time: {} seconds'.format(time.time() - start_time))
print('Completed...')
# Out:
#   7%|▋         | 14/200 [00:07<01:35,  1.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb Cell 9' in <cell line: 5>()
#      <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000008?line=12'>13</a>     request_count+=1
#      <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000008?line=13'>14</a>     if request_count % 5 == 0:
#      <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000008?line=14'>15</a>         # print(str(request_count) + " requests sent")
# ---> <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000008?line=15'>16</a>         time.sleep(np.random.uniform(sleep_min, sleep_max))
#      <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000008?line=16'>17</a>         # print('Elapsed Time: {} seconds'.format(time.time() - start_time))
#      <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000008?line=17'>18</a> print('Completed...')
#
# KeyboardInterrupt:

# %%
print(f'Out of the 200 sample data records, data for {len(check_dat)} records is available')
# Out:
# Out of the 200 sample data records, data for 14 records is available

# %%
df1 = pd.DataFrame(spotify_artists)
df2 = pd.DataFrame(artists)
df3 = pd.concat([df2,df1], axis=1, join='outer')
df3.to_csv('check.csv')

# %% [markdown]
# Checking if the artisrts that we extracted from spotify are same as in our dataset

# %%
count = 0
for i in tqdm(range(len(artists))):
    if pre_process_text(artists[i]) in pre_process_text(spotify_artists[i]):
        count+=1
count
# Out:
#   8%|▊         | 15/200 [00:00<00:00, 57879.08it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb Cell 13' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000012?line=0'>1</a> count = 0
#       <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000012?line=1'>2</a> for i in tqdm(range(len(artists))):
# ----> <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000012?line=2'>3</a>     if pre_process_text(artists[i]) in pre_process_text(spotify_artists[i]):
#       <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000012?line=3'>4</a>         count+=1
#       <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000012?line=4'>5</a> count
#
# IndexError: list index out of range

# %% [markdown]
# Extracting Data

# %%
'''
In track_preview_available function I am checking that the query returned by spotify's api is not empty and if its not I check if the preview url is available.

In is_same_artist function I check whether the artist the we found in our query is the same one from our dataset.
'''
def is_same_artist_and_title(query, artist, title, index):
    is_same_artist = pre_process_text(artist[index]) in pre_process_text(query['tracks']['items'][0]['artists'][0]['name'])
    is_same_title = pre_process_text(title[index]) in pre_process_text(query['tracks']['items'][0]['name'])
    return is_same_artist and is_same_title

    # if pre_process_text(artist[index]) in pre_process_text(query['tracks']['items'][0]['artists'][0]['name']):
    #     if pre_process_text(title[index]) in pre_process_text(query['tracks']['items'][0]['name']):
    #         return True
    #     else:
    #         return False
    # else:
    #     return False

def track_preview_available(query):
    if query['tracks']['items']:
        if query['tracks']['items'][0]['preview_url']:
            return True
        return True
        
def artist_available(query):
    if query['tracks']['items']:
        return True
    else:
        return False

def get_audio_features(track_id, chunk_size):
    audio_features_list = []

    for i in range(0, len(track_id), chunk_size):    
        track_id_list = track_id[i:i+chunk_size]
        results = sp.audio_features(track_id_list)
        results = [v for v in results if str(v) != 'None']
        audio_features_list.extend(results)

    return audio_features_list

# %%
sleep_min = 1
sleep_max = 3
request_count = 0
start_time = time.time()

preview_url = []
track_id = []
artist_id = []
track_popularity = []
artists_df = []
titles_df = []

for index in range(len(artists_clean)):
    # artist_name = spotify_artists[index]
    artist_name = artists_clean[index]
    song_title = titles_clean[index]
    search = f'artist:{artist_name} track:{song_title}'
    query = sp.search(search, type='track')


    # in the below line of code I am checking that the query returned by spotify's api is not empty and if its not I check if the preview url is available, and
    # even further I check a third condition whether the artist the we found in our query is the same from our dataset.


    # if query['tracks']['items'] and query['tracks']['items'][0]['preview_url'] and query['tracks']['items'][0]['artists'][0]['name'] in alpha_artists_titles[index]:
    if track_preview_available(query) and is_same_artist_and_title(query,artists,titles,index):
        preview_url.append(query['tracks']['items'][0]['preview_url'])
        track_id.append(query['tracks']['items'][0]['id'])
        artist_id.append(query['tracks']['items'][0]['artists'][0]['id'])
        track_popularity.append(query['tracks']['items'][0]['popularity'])
        artists_df.append(query['tracks']['items'][0]['artists'][0]['name'])
        titles_df.append(query['tracks']['items'][0]['name'])
        
         
    else:
        preview_url.append(None)
        track_id.append(None)
        artist_id.append(None)
        track_popularity.append(None)
        # artists_df.append(artists_clean[index])
        # titles_df.append(titles_clean[index])
        artists_df.append(query['tracks']['items'][0]['artists'][0]['name'])
        titles_df.append(query['tracks']['items'][0]['name'])

    request_count+=1
    if request_count % 5 == 0:
        print(str(request_count) + " artists uris fetched")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# 5 artists uris fetched
# Loop #: 5
# Elapsed Time: 2.441851854324341 seconds
# 10 artists uris fetched
# Loop #: 10
# Elapsed Time: 5.0771238803863525 seconds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb Cell 17' in <cell line: 13>()
#      <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000017?line=38'>39</a>     track_popularity.append(None)
#      <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000017?line=39'>40</a>     # artists_df.append(artists_clean[index])
#      <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000017?line=40'>41</a>     # titles_df.append(titles_clean[index])
# ---> <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000017?line=41'>42</a>     artists_df.append(query['tracks']['items'][0]['artists'][0]['name'])
#      <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000017?line=42'>43</a>     titles_df.append(query['tracks']['items'][0]['name'])
#      <a href='vscode-notebook-cell:/Users/ytkd/Desktop/Dataset_Creation/main_notebook.ipynb#ch0000017?line=44'>45</a> request_count+=1
#
# IndexError: list index out of range

# %%
track_data = pd.DataFrame(artists_df, columns=['artists'])
track_data['tracks'] = titles_df
track_data['artist_id'] = artist_id
track_data['track_id'] = track_id
track_data['track_popularity'] = track_popularity
track_data['track_url'] = preview_url

# %%
track_data
# Out:
#   artists                            tracks               artist_id  \
# 0  *NSYNC                       Bye Bye Bye  6Ff53KvcvAj5U7Z1vojB5o
# 1  *NSYNC                  It's Gonna Be Me                    None
# 2  *NSYNC  Tearin' up My Heart - Radio Edit                    None
# 3  *NSYNC                              Gone  6Ff53KvcvAj5U7Z1vojB5o
# 4  *NSYNC   Merry Christmas, Happy Holidays  6Ff53KvcvAj5U7Z1vojB5o
# 5  *NSYNC                   It Makes Me Ill  6Ff53KvcvAj5U7Z1vojB5o
# 6  *NSYNC                This I Promise You  6Ff53KvcvAj5U7Z1vojB5o
# 7  *NSYNC                               Pop  6Ff53KvcvAj5U7Z1vojB5o
# 8  *NSYNC      I Want You Back - Radio Edit  6Ff53KvcvAj5U7Z1vojB5o
# 9  *shels       Butterflies (on Luci's Way)                    None
#
#                  track_id  track_popularity  \
# 0  62bOmKYxYg7dhrC6gH9vFn              71.0
# 1                    None               NaN
# 2                    None               NaN
# 3  4CCUjYJPbSXLL23BFeBVbI              52.0
# 4  4v9WbaxW8HdjqfUiWYWsII              39.0
# 5  0gbysjaH16DW29QpUnowcx              46.0
# 6  46n2EGFnPC3tzWCN1Aqe26              66.0
# 7  0Jc8qF1mUPo1A96HE9QxZz              57.0
# 8  221LRlPHPuevgE1tuUlof9              61.0
# 9                    None               NaN
#
#                                            track_url
# 0  https://p.scdn.co/mp3-preview/612fd571c0216fa3...
# 1                                               None
# 2                                               None
# 3  https://p.scdn.co/mp3-preview/eea62070ce877996...
# 4  https://p.scdn.co/mp3-preview/158f2eafaa4f03f5...
# 5  https://p.scdn.co/mp3-preview/c00dc4528ddf44eb...
# 6  https://p.scdn.co/mp3-preview/0b9a69ffaf5fbb52...
# 7  https://p.scdn.co/mp3-preview/edcadba3c2b60c2f...
# 8  https://p.scdn.co/mp3-preview/3cbf84331a097fd1...
# 9                                               None

# %% [markdown]
# Extracting Features

# %%
# def get_audio_features(track_id, chunk_size):
#     audio_features_list = []

#     for i in range(0, len(track_id), chunk_size):    
#         track_id_list = track_id[i:i+chunk_size]
#         if track_id[i] is not None:
#             results = sp.audio_features(track_id_list)
#             results = [v for v in results if str(v) != 'None']
#             audio_features_list.extend(results)
#         else:
#             audio_features_list.extend(None)


#     return audio_features_list

# %%
def get_audio_features(track_id):
    request_count = 0
    start_time = time.time()
    features_dict = {}
    features_dict['acousticness'] = []
    features_dict['danceability'] = []
    features_dict['energy'] = []
    features_dict['instrumentalness'] = []
    features_dict['liveness'] = []
    features_dict['loudness'] = []
    features_dict['speechiness'] = []
    features_dict['tempo'] = []
    features_dict['valence'] = []

    for i in range(len(track_id)):    
        if track_id[i] is not None:
            features = sp.audio_features(track_id[i])
            features_dict['acousticness'].append(features[0]['acousticness'])
            features_dict['danceability'].append(features[0]['danceability'])
            features_dict['energy'].append(features[0]['energy'])
            features_dict['instrumentalness'].append(features[0]['instrumentalness'])
            features_dict['liveness'].append(features[0]['liveness'])
            features_dict['loudness'].append(features[0]['loudness'])
            features_dict['speechiness'].append(features[0]['speechiness'])
            features_dict['tempo'].append(features[0]['tempo'])
            features_dict['valence'].append(features[0]['valence'])
        else:
            features_dict['acousticness'].append(None)
            features_dict['danceability'].append(None)
            features_dict['energy'].append(None)
            features_dict['instrumentalness'].append(None)
            features_dict['liveness'].append(None)
            features_dict['loudness'].append(None)
            features_dict['speechiness'].append(None)
            features_dict['tempo'].append(None)
            features_dict['valence'].append(None)

        request_count+=1  
        if request_count % 5 == 0:
            print(str(request_count) + " artists's features extracted")
            time.sleep(np.random.uniform(sleep_min, sleep_max))
            print('Loop #: {}'.format(request_count))
            print('Elapsed Time: {} seconds'.format(time.time() - start_time))


    return features_dict

# %%
features_dict = get_audio_features(track_id)
# Out:
# 5 artists's features extracted
# Loop #: 5
# Elapsed Time: 2.9754562377929688 seconds
# 10 artists's features extracted
# Loop #: 10
# Elapsed Time: 5.924633026123047 seconds
# 15 artists's features extracted
# Loop #: 15
# Elapsed Time: 7.816481828689575 seconds
# 20 artists's features extracted
# Loop #: 20
# Elapsed Time: 9.872878074645996 seconds
# 25 artists's features extracted
# Loop #: 25
# Elapsed Time: 12.524617195129395 seconds
# 30 artists's features extracted
# Loop #: 30
# Elapsed Time: 14.685796976089478 seconds
# 35 artists's features extracted
# Loop #: 35
# Elapsed Time: 18.231149911880493 seconds
# 40 artists's features extracted
# Loop #: 40
# Elapsed Time: 21.643114805221558 seconds
# 45 artists's features extracted
# Loop #: 45
# Elapsed Time: 24.709187984466553 seconds
# 50 artists's features extracted
# Loop #: 50
# Elapsed Time: 27.042639017105103 seconds
# 55 artists's features extracted
# Loop #: 55
# Elapsed Time: 30.16559410095215 seconds
# 60 artists's features extracted
# Loop #: 60
# Elapsed Time: 32.64086413383484 seconds
# 65 artists's features extracted
# Loop #: 65
# Elapsed Time: 35.2332329750061 seconds
# 70 artists's features extracted
# Loop #: 70
# Elapsed Time: 38.155839920043945 seconds
# 75 artists's features extracted
# Loop #: 75
# Elapsed Time: 40.57103085517883 seconds
# 80 artists's features extracted
# Loop #: 80
# Elapsed Time: 43.1027090549469 seconds
# 85 artists's features extracted
# Loop #: 85
# Elapsed Time: 45.937922954559326 seconds
# 90 artists's features extracted
# Loop #: 90
# Elapsed Time: 48.85393714904785 seconds
# 95 artists's features extracted
# Loop #: 95
# Elapsed Time: 52.42582416534424 seconds
# 100 artists's features extracted
# Loop #: 100
# Elapsed Time: 54.07572102546692 seconds
# 105 artists's features extracted
# Loop #: 105
# Elapsed Time: 55.73375201225281 seconds
# 110 artists's features extracted
# Loop #: 110
# Elapsed Time: 57.52743601799011 seconds
# 115 artists's features extracted
# Loop #: 115
# Elapsed Time: 60.006832122802734 seconds
# 120 artists's features extracted
# Loop #: 120
# Elapsed Time: 62.18938899040222 seconds
# 125 artists's features extracted
# Loop #: 125
# Elapsed Time: 64.64829611778259 seconds
# 130 artists's features extracted
# Loop #: 130
# Elapsed Time: 66.22468900680542 seconds
# 135 artists's features extracted
# Loop #: 135
# Elapsed Time: 68.27556109428406 seconds
# 140 artists's features extracted
# Loop #: 140
# Elapsed Time: 70.42354488372803 seconds
# 145 artists's features extracted
# Loop #: 145
# Elapsed Time: 72.86656498908997 seconds
# 150 artists's features extracted
# Loop #: 150
# Elapsed Time: 76.15107297897339 seconds
# 155 artists's features extracted
# Loop #: 155
# Elapsed Time: 78.95119190216064 seconds
# 160 artists's features extracted
# Loop #: 160
# Elapsed Time: 82.16198801994324 seconds
# 165 artists's features extracted
# Loop #: 165
# Elapsed Time: 84.41465592384338 seconds
# 170 artists's features extracted
# Loop #: 170
# Elapsed Time: 86.66556310653687 seconds
# 175 artists's features extracted
# Loop #: 175
# Elapsed Time: 88.95286893844604 seconds
# 180 artists's features extracted
# Loop #: 180
# Elapsed Time: 92.46202611923218 seconds
# 185 artists's features extracted
# Loop #: 185
# Elapsed Time: 94.93868613243103 seconds
# 190 artists's features extracted
# Loop #: 190
# Elapsed Time: 98.47722506523132 seconds
# 195 artists's features extracted
# Loop #: 195
# Elapsed Time: 101.37907290458679 seconds
# 200 artists's features extracted
# Loop #: 200
# Elapsed Time: 103.20728206634521 seconds

# %%
temp = list(zip(features_dict['acousticness'],features_dict['danceability'],features_dict['energy'],features_dict['instrumentalness'],features_dict['liveness'],features_dict['loudness'],features_dict['speechiness'],features_dict['tempo'],features_dict['valence']))
data_features = pd.DataFrame(temp, columns=['acousticness','danceability','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence'])
data_features
# Out:
#      acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0         0.03100         0.610   0.926           0.00120    0.0821    -4.843
# 1             NaN           NaN     NaN               NaN       NaN       NaN
# 2             NaN           NaN     NaN               NaN       NaN       NaN
# 3         0.43000         0.704   0.409           0.00000    0.1090    -8.581
# 4         0.10400         0.643   0.939           0.00000    0.8810    -3.967
# ..            ...           ...     ...               ...       ...       ...
# 195       0.02890         0.193   0.485           0.84700    0.0999    -7.956
# 196           NaN           NaN     NaN               NaN       NaN       NaN
# 197       0.10900         0.789   0.881           0.00000    0.3550    -5.758
# 198       0.00103         0.895   0.412           0.00179    0.1280    -7.845
# 199           NaN           NaN     NaN               NaN       NaN       NaN
#
#      speechiness    tempo  valence
# 0         0.0479  172.638    0.861
# 1            NaN      NaN      NaN
# 2            NaN      NaN      NaN
# 3         0.0597  113.863    0.495
# 4         0.0463  104.999    0.756
# ..           ...      ...      ...
# 195       0.0437   90.001    0.127
# 196          NaN      NaN      NaN
# 197       0.0331  133.299    0.647
# 198       0.0645  122.223    0.183
# 199          NaN      NaN      NaN
#
# [200 rows x 9 columns]

# %%
final_df = pd.concat([track_data,data_features], axis=1, join='outer')
final_df
# Out:
#             artists                           tracks               artist_id  \
# 0            *NSYNC                      bye bye bye  6Ff53KvcvAj5U7Z1vojB5o
# 1            *NSYNC                 it s gonna be me                    None
# 2            *NSYNC              tearin  up my heart                    None
# 3            *NSYNC                             gone  6Ff53KvcvAj5U7Z1vojB5o
# 4            *NSYNC  merry christmas, happy holidays  6Ff53KvcvAj5U7Z1vojB5o
# ..              ...                              ...                     ...
# 195  65daysofstatic     heat death infinity splitter  6DVVsQAnpHdJjb1nYuOQ6g
# 196   Three 6 Mafia            sippin  on some syrup                    None
# 197   Three 6 Mafia                         stay fly  26s8LSolLfCIY88ysQbIuT
# 198   Three 6 Mafia                    late nite tip  26s8LSolLfCIY88ysQbIuT
# 199   Three 6 Mafia    it s hard out here for a pimp                    None
#
#                    track_id  track_popularity  \
# 0    62bOmKYxYg7dhrC6gH9vFn              71.0
# 1                      None               NaN
# 2                      None               NaN
# 3    4CCUjYJPbSXLL23BFeBVbI              52.0
# 4    4v9WbaxW8HdjqfUiWYWsII              39.0
# ..                      ...               ...
# 195  3PibgbUWMGaYZObGpvGhmJ              26.0
# 196                    None               NaN
# 197  5MYFw4T2gy52pOGBN4EYHS              69.0
# 198  75RK78POyFmg3u6O1cpBdr              51.0
# 199                    None               NaN
#
#                                              track_url  acousticness  \
# 0    https://p.scdn.co/mp3-preview/612fd571c0216fa3...       0.03100
# 1                                                 None           NaN
# 2                                                 None           NaN
# 3    https://p.scdn.co/mp3-preview/eea62070ce877996...       0.43000
# 4    https://p.scdn.co/mp3-preview/158f2eafaa4f03f5...       0.10400
# ..                                                 ...           ...
# 195  https://p.scdn.co/mp3-preview/2799b9f6b7e4fe22...       0.02890
# 196                                               None           NaN
# 197  https://p.scdn.co/mp3-preview/56db43014efeb814...       0.10900
# 198  https://p.scdn.co/mp3-preview/3e7e1d015ddb7feb...       0.00103
# 199                                               None           NaN
#
#      danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0           0.610   0.926           0.00120    0.0821    -4.843       0.0479
# 1             NaN     NaN               NaN       NaN       NaN          NaN
# 2             NaN     NaN               NaN       NaN       NaN          NaN
# 3           0.704   0.409           0.00000    0.1090    -8.581       0.0597
# 4           0.643   0.939           0.00000    0.8810    -3.967       0.0463
# ..            ...     ...               ...       ...       ...          ...
# 195         0.193   0.485           0.84700    0.0999    -7.956       0.0437
# 196           NaN     NaN               NaN       NaN       NaN          NaN
# 197         0.789   0.881           0.00000    0.3550    -5.758       0.0331
# 198         0.895   0.412           0.00179    0.1280    -7.845       0.0645
# 199           NaN     NaN               NaN       NaN       NaN          NaN
#
#        tempo  valence
# 0    172.638    0.861
# 1        NaN      NaN
# 2        NaN      NaN
# 3    113.863    0.495
# 4    104.999    0.756
# ..       ...      ...
# 195   90.001    0.127
# 196      NaN      NaN
# 197  133.299    0.647
# 198  122.223    0.183
# 199      NaN      NaN
#
# [200 rows x 15 columns]

# %%
# Downloading these songs according to track id
final_df.set_index('track_id',inplace=True)
final_df.to_csv('track_data.csv')

# %%
final_df
# Out:
#                                artists                           tracks  \
# track_id
# 62bOmKYxYg7dhrC6gH9vFn          *NSYNC                      bye bye bye
# None                            *NSYNC                 it s gonna be me
# None                            *NSYNC              tearin  up my heart
# 4CCUjYJPbSXLL23BFeBVbI          *NSYNC                             gone
# 4v9WbaxW8HdjqfUiWYWsII          *NSYNC  merry christmas, happy holidays
# ...                                ...                              ...
# 3PibgbUWMGaYZObGpvGhmJ  65daysofstatic     heat death infinity splitter
# None                     Three 6 Mafia            sippin  on some syrup
# 5MYFw4T2gy52pOGBN4EYHS   Three 6 Mafia                         stay fly
# 75RK78POyFmg3u6O1cpBdr   Three 6 Mafia                    late nite tip
# None                     Three 6 Mafia    it s hard out here for a pimp
#
#                                      artist_id  track_popularity  \
# track_id
# 62bOmKYxYg7dhrC6gH9vFn  6Ff53KvcvAj5U7Z1vojB5o              71.0
# None                                      None               NaN
# None                                      None               NaN
# 4CCUjYJPbSXLL23BFeBVbI  6Ff53KvcvAj5U7Z1vojB5o              52.0
# 4v9WbaxW8HdjqfUiWYWsII  6Ff53KvcvAj5U7Z1vojB5o              39.0
# ...                                        ...               ...
# 3PibgbUWMGaYZObGpvGhmJ  6DVVsQAnpHdJjb1nYuOQ6g              26.0
# None                                      None               NaN
# 5MYFw4T2gy52pOGBN4EYHS  26s8LSolLfCIY88ysQbIuT              69.0
# 75RK78POyFmg3u6O1cpBdr  26s8LSolLfCIY88ysQbIuT              51.0
# None                                      None               NaN
#
#                                                                 track_url  \
# track_id
# 62bOmKYxYg7dhrC6gH9vFn  https://p.scdn.co/mp3-preview/612fd571c0216fa3...
# None                                                                 None
# None                                                                 None
# 4CCUjYJPbSXLL23BFeBVbI  https://p.scdn.co/mp3-preview/eea62070ce877996...
# 4v9WbaxW8HdjqfUiWYWsII  https://p.scdn.co/mp3-preview/158f2eafaa4f03f5...
# ...                                                                   ...
# 3PibgbUWMGaYZObGpvGhmJ  https://p.scdn.co/mp3-preview/2799b9f6b7e4fe22...
# None                                                                 None
# 5MYFw4T2gy52pOGBN4EYHS  https://p.scdn.co/mp3-preview/56db43014efeb814...
# 75RK78POyFmg3u6O1cpBdr  https://p.scdn.co/mp3-preview/3e7e1d015ddb7feb...
# None                                                                 None
#
#                         acousticness  danceability  energy  instrumentalness  \
# track_id
# 62bOmKYxYg7dhrC6gH9vFn       0.03100         0.610   0.926           0.00120
# None                             NaN           NaN     NaN               NaN
# None                             NaN           NaN     NaN               NaN
# 4CCUjYJPbSXLL23BFeBVbI       0.43000         0.704   0.409           0.00000
# 4v9WbaxW8HdjqfUiWYWsII       0.10400         0.643   0.939           0.00000
# ...                              ...           ...     ...               ...
# 3PibgbUWMGaYZObGpvGhmJ       0.02890         0.193   0.485           0.84700
# None                             NaN           NaN     NaN               NaN
# 5MYFw4T2gy52pOGBN4EYHS       0.10900         0.789   0.881           0.00000
# 75RK78POyFmg3u6O1cpBdr       0.00103         0.895   0.412           0.00179
# None                             NaN           NaN     NaN               NaN
#
#                         liveness  loudness  speechiness    tempo  valence
# track_id
# 62bOmKYxYg7dhrC6gH9vFn    0.0821    -4.843       0.0479  172.638    0.861
# None                         NaN       NaN          NaN      NaN      NaN
# None                         NaN       NaN          NaN      NaN      NaN
# 4CCUjYJPbSXLL23BFeBVbI    0.1090    -8.581       0.0597  113.863    0.495
# 4v9WbaxW8HdjqfUiWYWsII    0.8810    -3.967       0.0463  104.999    0.756
# ...                          ...       ...          ...      ...      ...
# 3PibgbUWMGaYZObGpvGhmJ    0.0999    -7.956       0.0437   90.001    0.127
# None                         NaN       NaN          NaN      NaN      NaN
# 5MYFw4T2gy52pOGBN4EYHS    0.3550    -5.758       0.0331  133.299    0.647
# 75RK78POyFmg3u6O1cpBdr    0.1280    -7.845       0.0645  122.223    0.183
# None                         NaN       NaN          NaN      NaN      NaN
#
# [200 rows x 14 columns]

# %%
if os.path.exists('/Users/ytkd/Desktop/downloaded_songs') is False:
    os.mkdir('/Users/ytkd/Desktop/downloaded_songs')

audio_path = '/Users/ytkd/Desktop/downloaded_songs'
for i,url in enumerate(preview_url):
    if url is not None:
        response = requests.get(url, verify=False)
        if os.path.exists(f'{audio_path}/{track_id[i][:1]}') is False:
            os.mkdir(f'{audio_path}/{track_id[i][:1]}')
        open(f"{os.path.join(audio_path,track_id[i][:1],track_id[i]+'.mp3')}", 'wb').write(response.content)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'p.scdn.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
count = 0
for id in preview_url:
    if id is None:
        count = count + 1
count
print(f'Out of 200 sample records the preview url is available for only {int(200-count)} songs')
# Out:
# Out of 200 sample records the preview url is available for only 91 songs

# %%
x = sp.search('artist: 5 Seconds of Summer track: she looks so perfect',type='track')
x['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#      'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#      'id': '5Rl15oVamLq7FbSb0NNBNy',
#      'name': '5 Seconds of Summer',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2LkWHNNHgD6BRNeZI2SL1L'},
#    'href': 'https://api.spotify.com/v1/albums/2LkWHNNHgD6BRNeZI2SL1L',
#    'id': '2LkWHNNHgD6BRNeZI2SL1L',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27393432e914046a003229378da',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0293432e914046a003229378da',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485193432e914046a003229378da',
#      'width': 64}],
#    'name': '5 Seconds Of Summer',
#    'release_date': '2014-06-27',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:2LkWHNNHgD6BRNeZI2SL1L'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#     'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#     'id': '5Rl15oVamLq7FbSb0NNBNy',
#     'name': '5 Seconds of Summer',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 202496,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71400377'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1gugDOSMREb34Xo0c1PlxM'},
#   'href': 'https://api.spotify.com/v1/tracks/1gugDOSMREb34Xo0c1PlxM',
#   'id': '1gugDOSMREb34Xo0c1PlxM',
#   'is_local': False,
#   'name': 'She Looks So Perfect',
#   'popularity': 73,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1gugDOSMREb34Xo0c1PlxM'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#      'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#      'id': '5Rl15oVamLq7FbSb0NNBNy',
#      'name': '5 Seconds of Summer',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7FPkaI35RqABwOd1bOHi05'},
#    'href': 'https://api.spotify.com/v1/albums/7FPkaI35RqABwOd1bOHi05',
#    'id': '7FPkaI35RqABwOd1bOHi05',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27399514ca63f7978b99e681ebe',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0299514ca63f7978b99e681ebe',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485199514ca63f7978b99e681ebe',
#      'width': 64}],
#    'name': 'She Looks So Perfect (B-Sides)',
#    'release_date': '2014',
#    'release_date_precision': 'year',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:7FPkaI35RqABwOd1bOHi05'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#     'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#     'id': '5Rl15oVamLq7FbSb0NNBNy',
#     'name': '5 Seconds of Summer',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 202967,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71400504'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3dljWRIrBeb8YXte1mvjX5'},
#   'href': 'https://api.spotify.com/v1/tracks/3dljWRIrBeb8YXte1mvjX5',
#   'id': '3dljWRIrBeb8YXte1mvjX5',
#   'is_local': False,
#   'name': 'She Looks So Perfect - Acoustic',
#   'popularity': 40,
#   'preview_url': None,
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:3dljWRIrBeb8YXte1mvjX5'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#      'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#      'id': '5Rl15oVamLq7FbSb0NNBNy',
#      'name': '5 Seconds of Summer',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7FPkaI35RqABwOd1bOHi05'},
#    'href': 'https://api.spotify.com/v1/albums/7FPkaI35RqABwOd1bOHi05',
#    'id': '7FPkaI35RqABwOd1bOHi05',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27399514ca63f7978b99e681ebe',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0299514ca63f7978b99e681ebe',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485199514ca63f7978b99e681ebe',
#      'width': 64}],
#    'name': 'She Looks So Perfect (B-Sides)',
#    'release_date': '2014',
#    'release_date_precision': 'year',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:7FPkaI35RqABwOd1bOHi05'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#     'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#     'id': '5Rl15oVamLq7FbSb0NNBNy',
#     'name': '5 Seconds of Summer',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 204231,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71400501'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5m1kHRzOiqH7aqBXPD17Vw'},
#   'href': 'https://api.spotify.com/v1/tracks/5m1kHRzOiqH7aqBXPD17Vw',
#   'id': '5m1kHRzOiqH7aqBXPD17Vw',
#   'is_local': False,
#   'name': 'She Looks So Perfect - Mikey Demo Vocal',
#   'popularity': 38,
#   'preview_url': None,
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:5m1kHRzOiqH7aqBXPD17Vw'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#      'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#      'id': '5Rl15oVamLq7FbSb0NNBNy',
#      'name': '5 Seconds of Summer',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7FPkaI35RqABwOd1bOHi05'},
#    'href': 'https://api.spotify.com/v1/albums/7FPkaI35RqABwOd1bOHi05',
#    'id': '7FPkaI35RqABwOd1bOHi05',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27399514ca63f7978b99e681ebe',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0299514ca63f7978b99e681ebe',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485199514ca63f7978b99e681ebe',
#      'width': 64}],
#    'name': 'She Looks So Perfect (B-Sides)',
#    'release_date': '2014',
#    'release_date_precision': 'year',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:7FPkaI35RqABwOd1bOHi05'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#     'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#     'id': '5Rl15oVamLq7FbSb0NNBNy',
#     'name': '5 Seconds of Summer',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 203349,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71400499'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4xry6szgFmOrQNG2DEwKPz'},
#   'href': 'https://api.spotify.com/v1/tracks/4xry6szgFmOrQNG2DEwKPz',
#   'id': '4xry6szgFmOrQNG2DEwKPz',
#   'is_local': False,
#   'name': 'She Looks So Perfect - Ash Demo Vocal',
#   'popularity': 34,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:4xry6szgFmOrQNG2DEwKPz'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#      'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#      'id': '5Rl15oVamLq7FbSb0NNBNy',
#      'name': '5 Seconds of Summer',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5XfkdKrtvNcsVVtGobQiLW'},
#    'href': 'https://api.spotify.com/v1/albums/5XfkdKrtvNcsVVtGobQiLW',
#    'id': '5XfkdKrtvNcsVVtGobQiLW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273eb75bebca1028c4e295fe795',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02eb75bebca1028c4e295fe795',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851eb75bebca1028c4e295fe795',
#      'width': 64}],
#    'name': 'Meet You There Tour Live',
#    'release_date': '2018-12-21',
#    'release_date_precision': 'day',
#    'total_tracks': 20,
#    'type': 'album',
#    'uri': 'spotify:album:5XfkdKrtvNcsVVtGobQiLW'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#     'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#     'id': '5Rl15oVamLq7FbSb0NNBNy',
#     'name': '5 Seconds of Summer',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 281455,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71807764'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5S7e5D9r5TIPsEjTiDtqPi'},
#   'href': 'https://api.spotify.com/v1/tracks/5S7e5D9r5TIPsEjTiDtqPi',
#   'id': '5S7e5D9r5TIPsEjTiDtqPi',
#   'is_local': False,
#   'name': 'She Looks So Perfect - Live',
#   'popularity': 36,
#   'preview_url': None,
#   'track_number': 19,
#   'type': 'track',
#   'uri': 'spotify:track:5S7e5D9r5TIPsEjTiDtqPi'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#      'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#      'id': '5Rl15oVamLq7FbSb0NNBNy',
#      'name': '5 Seconds of Summer',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3KwiuDhdb8W9IJ3kvvORKU'},
#    'href': 'https://api.spotify.com/v1/albums/3KwiuDhdb8W9IJ3kvvORKU',
#    'id': '3KwiuDhdb8W9IJ3kvvORKU',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273055addd96071725be76d6da9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02055addd96071725be76d6da9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851055addd96071725be76d6da9',
#      'width': 64}],
#    'name': 'LIVESOS',
#    'release_date': '2014-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:3KwiuDhdb8W9IJ3kvvORKU'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#     'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#     'id': '5Rl15oVamLq7FbSb0NNBNy',
#     'name': '5 Seconds of Summer',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 266372,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71405562'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3LDmjPBJFdXyb1tzxncoOr'},
#   'href': 'https://api.spotify.com/v1/tracks/3LDmjPBJFdXyb1tzxncoOr',
#   'id': '3LDmjPBJFdXyb1tzxncoOr',
#   'is_local': False,
#   'name': 'She Looks So Perfect - Live',
#   'popularity': 24,
#   'preview_url': None,
#   'track_number': 14,
#   'type': 'track',
#   'uri': 'spotify:track:3LDmjPBJFdXyb1tzxncoOr'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/23dOSX3k9eTyyQIm6KHX52'},
#    'href': 'https://api.spotify.com/v1/albums/23dOSX3k9eTyyQIm6KHX52',
#    'id': '23dOSX3k9eTyyQIm6KHX52',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a73d0dbf65700083ede70726',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a73d0dbf65700083ede70726',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a73d0dbf65700083ede70726',
#      'width': 64}],
#    'name': 'Pop Nostalgia',
#    'release_date': '2018-01-26',
#    'release_date_precision': 'day',
#    'total_tracks': 23,
#    'type': 'album',
#    'uri': 'spotify:album:23dOSX3k9eTyyQIm6KHX52'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#     'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#     'id': '5Rl15oVamLq7FbSb0NNBNy',
#     'name': '5 Seconds of Summer',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 203493,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71400377'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2TYmpZmLPM8unQmYwZir1i'},
#   'href': 'https://api.spotify.com/v1/tracks/2TYmpZmLPM8unQmYwZir1i',
#   'id': '2TYmpZmLPM8unQmYwZir1i',
#   'is_local': False,
#   'name': 'She Looks So Perfect',
#   'popularity': 25,
#   'preview_url': None,
#   'track_number': 14,
#   'type': 'track',
#   'uri': 'spotify:track:2TYmpZmLPM8unQmYwZir1i'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#      'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#      'id': '5Rl15oVamLq7FbSb0NNBNy',
#      'name': '5 Seconds of Summer',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/01F3p3sDM4wF9Fk4sxBPye'},
#    'href': 'https://api.spotify.com/v1/albums/01F3p3sDM4wF9Fk4sxBPye',
#    'id': '01F3p3sDM4wF9Fk4sxBPye',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fef3264111f1405ff37b4e78',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fef3264111f1405ff37b4e78',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fef3264111f1405ff37b4e78',
#      'width': 64}],
#    'name': 'She Looks So Perfect',
#    'release_date': '2014-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 3,
#    'type': 'album',
#    'uri': 'spotify:album:01F3p3sDM4wF9Fk4sxBPye'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#     'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#     'id': '5Rl15oVamLq7FbSb0NNBNy',
#     'name': '5 Seconds of Summer',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 202967,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71400504'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2HelEt0abz4t7KQjvNz154'},
#   'href': 'https://api.spotify.com/v1/tracks/2HelEt0abz4t7KQjvNz154',
#   'id': '2HelEt0abz4t7KQjvNz154',
#   'is_local': False,
#   'name': 'She Looks So Perfect - Acoustic',
#   'popularity': 23,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2HelEt0abz4t7KQjvNz154'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#      'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#      'id': '5Rl15oVamLq7FbSb0NNBNy',
#      'name': '5 Seconds of Summer',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2HO2oCe6AM8rGKbiCBEEAZ'},
#    'href': 'https://api.spotify.com/v1/albums/2HO2oCe6AM8rGKbiCBEEAZ',
#    'id': '2HO2oCe6AM8rGKbiCBEEAZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27339a6050f8800fcc1e4f65f43',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0239a6050f8800fcc1e4f65f43',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485139a6050f8800fcc1e4f65f43',
#      'width': 64}],
#    'name': 'LIVESOS',
#    'release_date': '2014-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:2HO2oCe6AM8rGKbiCBEEAZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#     'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#     'id': '5Rl15oVamLq7FbSb0NNBNy',
#     'name': '5 Seconds of Summer',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 266372,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71405562'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1MU7Kg39DENOnU9UblcsNE'},
#   'href': 'https://api.spotify.com/v1/tracks/1MU7Kg39DENOnU9UblcsNE',
#   'id': '1MU7Kg39DENOnU9UblcsNE',
#   'is_local': False,
#   'name': 'She Looks So Perfect - Live',
#   'popularity': 32,
#   'preview_url': None,
#   'track_number': 14,
#   'type': 'track',
#   'uri': 'spotify:track:1MU7Kg39DENOnU9UblcsNE'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/59uhDlTqyUMLqKfEeHsRHi'},
#    'href': 'https://api.spotify.com/v1/albums/59uhDlTqyUMLqKfEeHsRHi',
#    'id': '59uhDlTqyUMLqKfEeHsRHi',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fb1d6bb468c58d39e50ef927',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fb1d6bb468c58d39e50ef927',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fb1d6bb468c58d39e50ef927',
#      'width': 64}],
#    'name': 'Pool Party',
#    'release_date': '2018-05-25',
#    'release_date_precision': 'day',
#    'total_tracks': 25,
#    'type': 'album',
#    'uri': 'spotify:album:59uhDlTqyUMLqKfEeHsRHi'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#     'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#     'id': '5Rl15oVamLq7FbSb0NNBNy',
#     'name': '5 Seconds of Summer',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 204012,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71400377'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/164LmXXk3bU11iZ6yajQy7'},
#   'href': 'https://api.spotify.com/v1/tracks/164LmXXk3bU11iZ6yajQy7',
#   'id': '164LmXXk3bU11iZ6yajQy7',
#   'is_local': False,
#   'name': 'She Looks So Perfect',
#   'popularity': 17,
#   'preview_url': None,
#   'track_number': 16,
#   'type': 'track',
#   'uri': 'spotify:track:164LmXXk3bU11iZ6yajQy7'}]

# %%
test = sp.search('artist:Coldplay track:Fix You', type='track')
test['tracks']['href']
# Out:
# 'https://api.spotify.com/v1/search?query=artist%3AColdplay+track%3AFix+You&type=track&offset=0&limit=10'

# %%
import json
with open('test.json', 'w') as convert_file:
     convert_file.write(json.dumps(test))

# %%
# create a histigram and check file names
